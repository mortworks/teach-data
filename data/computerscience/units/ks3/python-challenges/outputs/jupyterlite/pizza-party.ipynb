# %% [markdown]
# # Pizza Party Planner
#
# You’re planning a party. Each pizza feeds **4 guests**. Ask for the number of guests, calculate the pizzas needed (rounding up), and print the result.

# %%
guests = int(input("How many guests are coming to the party? "))
pizzas = (guests + 3) // 4
print("You will need", pizzas, "pizzas.")
# Out:
# How many guests are coming to the party?  45
# You will need 12 pizzas.

# %%
assert pizzas_needed(7) == 2
assert pizzas_needed(12) == 3
assert pizzas_needed(1) == 1
print("✅ All tests passed!")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 assert pizzas_needed(7) == 2
#       2 assert pizzas_needed(12) == 3
#       3 assert pizzas_needed(1) == 1
#
# NameError: name 'pizzas_needed' is not defined

# %% [markdown]
# ### 🔍 Extension ideas
# - Change it so each pizza serves 3 guests instead.
# - Ask how many slices each person eats, then calculate pizzas (8 slices per pizza).
